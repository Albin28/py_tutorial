# %%
str1 = "Hello"
str2 = "World"
concat = str1 + " " + str2
print("Concatenated string:", concat)
print("Substring (0:5):", concat[0:5])
# Out:
# Concatenated string: Hello World
# Substring (0:5): Hello
